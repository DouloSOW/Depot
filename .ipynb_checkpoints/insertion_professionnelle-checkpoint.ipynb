# %%
#Appel du notebook contenant les packages
# %run ./head.ipynb
#Appel du notebook contenant des fonctions définies
# %run ./function.ipynb
#Racine principale de récupération des données
glob_path = "https://data.enseignementsup-recherche.gouv.fr/api/records/1.0/search/?dataset="
# Out:
# Tout est ok !

# %% [markdown]
# ### 1.3 INSERTION PROFESSIONNEL
#
#
#
# https://data.enseignementsup-recherche.gouv.fr/api/records/1.0/search/?dataset=fr-esr-insertion_professionnelle-lp&q=&rows=1500&facet=annee&facet=diplome&facet=numero_de_l_etablissement&facet=etablissement&facet=academie&facet=domaine&facet=code_de_la_discipline&facet=discipline&facet=situation&facet=cle_etab&facet=cle_disc&facet=id_paysage&refine.annee=2018

# %%
insertion = glob_path + "fr-esr-insertion_professionnelle-"
niveau = ["lp", "master"]
complement = "&q=&rows=1500&sort=-annee&facet=annee&facet=diplome&facet=numero_de_l_etablissement&facet=etablissement&facet=academie&facet=domaine&facet=code_de_la_discipline&facet=discipline&facet=situation&facet=cle_etab&facet=cle_disc&facet=id_paysage&refine.annee=2018"

# %%
#Récupération selon le niveau
data_insertion = [requests.get(insertion + niveau[x] + complement) for x in range(2)]

# %%
#Conversion de json à pd.Dataframe
data_insertion = [pd.json_normalize(x.json()['records'][:]) for x in data_insertion ]

# %%
###Les données selon le niveau sont identifiées par la varibale datsetid

# %%
data_insertion[0].shape
# Out:
# (1432, 36)

# %%
data_insertion[1].shape
# Out:
# (1500, 36)

# %%
glob_data_insertion = pd.concat(data_insertion)
glob_data_insertion.columns = [c.replace('fields.', '') for c in list(glob_data_insertion.columns) ]

# %%
sns.countplot(data=glob_data_insertion, y='remarque', order=glob_data_insertion.remarque.value_counts().index )
# Out:
# <AxesSubplot:xlabel='count', ylabel='remarque'>

# %%
#On garde les établissements dont les données sont jugés pertinentes
glob_data_insertion = glob_data_insertion[glob_data_insertion.remarque.isna()]

# %%
#La variable remarque nous permet de décider quels sont les établissement intéressants à inclure dans l'analyse au regard de la représentativité

# %%
df_insertion = glob_data_insertion.copy()

# %%
df_insertion = df_insertion.drop(["datasetid", "recordid", "record_timestamp", "remarque", 'etablissementactuel'], axis = 1)

# %%
df_insertion
# Out:
#                                              discipline  \
# 0     Ensemble formations juridiques, économiques et...
# 1                                              Économie
# 2                                               Gestion
# 3                                               Gestion
# 4                                Lettres, langues, arts
# ...                                                 ...
# 1495             Ensemble sciences humaines et sociales
# 1496                  Sciences de la vie et de la terre
# 1497                  Sciences de la vie et de la terre
# 1498                             Sciences fondamentales
# 1499                            Sciences de l'ingénieur
#
#      salaire_brut_annuel_estime salaire_net_mensuel_regional_3eme_quartile  \
# 0                         27000                                       2240
# 1                            ns                                       2240
# 2                         27900                                       2240
# 3                         28200                                       2240
# 4                            ns                                       2240
# ...                         ...                                        ...
# 1495                      32800                                       2700
# 1496                         ns                                       2700
# 1497                         ns                                       2700
# 1498                         ns                                       2700
# 1499                         ns                                       2700
#
#      salaire_net_mensuel_median_regional   cle_disc taux_de_reponse  \
# 0                                   1860  disc01_18              78
# 1                                   1860  disc03_18              81
# 2                                   1860  disc04_18              75
# 3                                   1860  disc04_30              75
# 4                                   1860  disc06_18              63
# ...                                  ...        ...             ...
# 1495                                2170  disc07_30              69
# 1496                                2170  disc13_18              81
# 1497                                2170  disc13_30              81
# 1498                                2170  disc14_18              72
# 1499                                2170  disc15_30              64
#
#      emplois_cadre_ou_professions_intermediaires taux_dinsertion  \
# 0                                             50              96
# 1                                             ns              90
# 2                                             56             100
# 3                                             54              98
# 4                                             ns              ns
# ...                                          ...             ...
# 1495                                          89              88
# 1496                                          ns              ns
# 1497                                          ns              ns
# 1498                                          ns              ns
# 1499                                          ns              ns
#
#      emplois_exterieurs_a_la_region_de_luniversite emplois_stables  \
# 0                                               34              82
# 1                                               ns              ns
# 2                                               24              90
# 3                                               24              94
# 4                                               ns              ns
# ...                                            ...             ...
# 1495                                            23              77
# 1496                                            ns              ns
# 1497                                            ns              ns
# 1498                                            ns              ns
# 1499                                            ns              ns
#
#           diplome salaire_net_median_des_emplois_a_temps_plein  \
# 0     LICENCE PRO                                         1730
# 1     LICENCE PRO                                           ns
# 2     LICENCE PRO                                         1790
# 3     LICENCE PRO                                         1810
# 4     LICENCE PRO                                           ns
# ...           ...                                          ...
# 1495   MASTER LMD                                         2100
# 1496   MASTER LMD                                           ns
# 1497   MASTER LMD                                           ns
# 1498   MASTER LMD                                           ns
# 1499   MASTER LMD                                           ns
#
#      poids_de_la_discipline taux_de_chomage_regional code_du_domaine  \
# 0                        49                        9             DEG
# 1                        16                        9             DEG
# 2                        27                        9             DEG
# 3                        27                        9             DEG
# 4                         1                        9             LLA
# ...                     ...                      ...             ...
# 1495                     20                      7.7             SHS
# 1496                      5                      7.7             STS
# 1497                      5                      7.7             STS
# 1498                      6                      7.7             STS
# 1499                      6                      7.7             STS
#
#      emplois_a_temps_plein code_de_la_discipline de_diplomes_boursiers  \
# 0                       95                disc01                    14
# 1                       ns                disc03                    14
# 2                       92                disc04                    14
# 3                       96                disc04                    14
# 4                       ns                disc06                    14
# ...                    ...                   ...                   ...
# 1495                    93                disc07                    13
# 1496                    ns                disc13                    13
# 1497                    ns                disc13                    13
# 1498                    ns                disc14                    13
# 1499                    ns                disc15                    13
#
#         academie numero_de_l_etablissement                          domaine  \
# 0           Nice                  0060931E       Droit, économie et gestion
# 1           Nice                  0060931E       Droit, économie et gestion
# 2           Nice                  0060931E       Droit, économie et gestion
# 3           Nice                  0060931E       Droit, économie et gestion
# 4           Nice                  0060931E           Lettres, langues, arts
# ...          ...                       ...                              ...
# 1495  Versailles                  0951793H    Sciences humaines et sociales
# 1496  Versailles                  0951793H  Sciences, technologies et santé
# 1497  Versailles                  0951793H  Sciences, technologies et santé
# 1498  Versailles                  0951793H  Sciences, technologies et santé
# 1499  Versailles                  0951793H  Sciences, technologies et santé
#
#      nombre_de_reponses femmes salaire_net_mensuel_regional_1er_quartile  \
# 0                    91     60                                      1410
# 1                    29     ns                                      1410
# 2                    49     51                                      1410
# 3                    49     51                                      1410
# 4                     3     ns                                      1410
# ...                 ...    ...                                       ...
# 1495                 85     58                                      1650
# 1496                 26     ns                                      1650
# 1497                 26     ns                                      1650
# 1498                 25     ns                                      1650
# 1499                 25     ns                                      1650
#
#                         cle_etab emplois_cadre                 situation  \
# 0     Nice - Sophia-Antipolis_18             7  18 mois après le diplôme
# 1     Nice - Sophia-Antipolis_18            ns  18 mois après le diplôme
# 2     Nice - Sophia-Antipolis_18             6  18 mois après le diplôme
# 3     Nice - Sophia-Antipolis_30             6  30 mois après le diplôme
# 4     Nice - Sophia-Antipolis_18            ns  18 mois après le diplôme
# ...                          ...           ...                       ...
# 1495           Cergy-Pontoise_30            71  30 mois après le diplôme
# 1496           Cergy-Pontoise_18            ns  18 mois après le diplôme
# 1497           Cergy-Pontoise_30            ns  30 mois après le diplôme
# 1498           Cergy-Pontoise_18            ns  18 mois après le diplôme
# 1499           Cergy-Pontoise_30            ns  30 mois après le diplôme
#
#      annee id_paysage            etablissement code_de_l_academie
# 0     2018      7CYWd  Nice - Sophia-Antipolis                A23
# 1     2018      7CYWd  Nice - Sophia-Antipolis                A23
# 2     2018      7CYWd  Nice - Sophia-Antipolis                A23
# 3     2018      7CYWd  Nice - Sophia-Antipolis                A23
# 4     2018      7CYWd  Nice - Sophia-Antipolis                A23
# ...    ...        ...                      ...                ...
# 1495  2018      W6CUQ           Cergy-Pontoise                A25
# 1496  2018      W6CUQ           Cergy-Pontoise                A25
# 1497  2018      W6CUQ           Cergy-Pontoise                A25
# 1498  2018      W6CUQ           Cergy-Pontoise                A25
# 1499  2018      W6CUQ           Cergy-Pontoise                A25
#
# [2601 rows x 31 columns]

# %%
#import ipynb.fs.full
#.fs.full.function import miss, visualisation

# %%
missings = miss(df_insertion)

# %%
viz_na(missings,0)

# %%
df_insertion[['taux_de_reponse', 'nombre_de_reponses']].isna().sum()
# Out:
# taux_de_reponse       77
# nombre_de_reponses    60
# dtype: int64

# %%
sns.countplot(data=df_insertion[~df_insertion['etablissementactuel'].isna()], y='etablissementactuel', order=df_insertion.etablissementactuel.value_counts().index, hue = 'diplome')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'etablissementactuel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\SOWDOU~1\AppData\Local\Temp/ipykernel_1512/827808184.py in <module>
# ----> 1 sns.countplot(data=df_insertion[~df_insertion['etablissementactuel'].isna()], y='etablissementactuel', order=df_insertion.etablissementactuel.value_counts().index, hue = 'diplome')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'etablissementactuel'
