# %%
#!pip install jyquickhelper
from jyquickhelper import add_notebook_menu


#Pour les api et données requetables
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## <center>1. Importation des données</center>

# %%
#Racine principale de récupération des données
glob_path = "https://data.enseignementsup-recherche.gouv.fr/api/records/1.0/search/?dataset="

# %% [markdown]
# ### 1.2 Vœux de poursuite d'études et de réorientation dans l'enseignement supérieur et réponses des établissements
#
#
#
# https://data.enseignementsup-recherche.gouv.fr/explore/dataset/fr-esr-parcoursup/information/

# %% [markdown]
# ###### On a 12760 lignes d'individus et l'Api ne permet pas de récupérer plus de 10 000 lignes et donc on a troué comme astuce de récupérer selon le type de l'établissement avant de merger les bases

# %%
#Segmentation pour pouvoir tout récupérer car l'API n'autorise pas plus de 10 000 lignes 
type_etablissement = ["2_Lyc%C3%A9es", "1_Universit%C3%A9s", "3_Autres+formations"]

# %%
#Le lien de récupération
voeux_poursuite = glob_path+"fr-esr-parcoursup&rows=6020&sort=tri&facet=session&facet=contrat_etab&facet=cod_uai&facet=g_ea_lib_vx&facet=dep_lib&facet=region_etab_aff&facet=acad_mies&facet=select_form&facet=fili&facet=form_lib_voe_acc&facet=regr_forma&facet=fil_lib_voe_acc&facet=detail_forma&facet=tri&facet=cod_aff_form&q="

# %%
#Récupération selon le type d'établissement
data_etablissement = [requests.get(voeux_poursuite + type_etablissement[x]) for x in range(3)]

# %%
#Vérification
data_etablissement
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>]

# %%
#Conversion de json à pd.Dataframe
data_etablissement = [pd.json_normalize(x.json()['records'][:]) for x in data_etablissement ]

# %%
glob_data = pd.concat(data_etablissement)
glob_data.columns = [c.replace('fields.', '') for c in list(glob_data.columns) ]

# %%
# Import seaborn
import seaborn as sns
# Apply the default theme
sns.set_theme()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#sns.catplot(data=glob_data[:], kind="swarm", x="contrat_etab", y="acc_tot", hue="select_form")

# %%
#!pip install pandas-profiling --user

# %% [markdown]
# ### 1.3 INSERTION PROFESSIONNEL
#
#
#
# https://data.enseignementsup-recherche.gouv.fr/api/records/1.0/search/?dataset=fr-esr-insertion_professionnelle-lp&q=&rows=1500&facet=annee&facet=diplome&facet=numero_de_l_etablissement&facet=etablissement&facet=academie&facet=domaine&facet=code_de_la_discipline&facet=discipline&facet=situation&facet=cle_etab&facet=cle_disc&facet=id_paysage&refine.annee=2018

# %%
insertion = glob_path + "fr-esr-insertion_professionnelle-"
niveau = ["lp", "master"]
complement = "&q=&rows=1500&sort=-annee&facet=annee&facet=diplome&facet=numero_de_l_etablissement&facet=etablissement&facet=academie&facet=domaine&facet=code_de_la_discipline&facet=discipline&facet=situation&facet=cle_etab&facet=cle_disc&facet=id_paysage&refine.annee=2018"

# %%
#Récupération selon le niveau
data_insertion = [requests.get(insertion + niveau[x] + complement) for x in range(2)]

# %%
#Conversion de json à pd.Dataframe
data_insertion = [pd.json_normalize(x.json()['records'][:]) for x in data_insertion ]

# %%
###Les données selon le niveau sont identifiées par la varibale datsetid

# %%
data_insertion[0].shape
# Out:
# (1432, 36)

# %%
data_insertion[1].shape
# Out:
# (1500, 36)

# %%
glob_data_insertion = pd.concat(data_insertion)
glob_data_insertion.columns = [c.replace('fields.', '') for c in list(glob_data_insertion.columns) ]

# %%
glob_data_insertion.head()
# Out:
#                              datasetid  \
# 0  fr-esr-insertion_professionnelle-lp
# 1  fr-esr-insertion_professionnelle-lp
# 2  fr-esr-insertion_professionnelle-lp
# 3  fr-esr-insertion_professionnelle-lp
# 4  fr-esr-insertion_professionnelle-lp
#
#                                    recordid                  record_timestamp  \
# 0  da765b6a4d45dd6886a8baeba37997c653f36b41  2021-12-15T22:16:37.978000+00:00
# 1  fd7af98d5194b196646e8a56d246429bfb6d3fd3  2021-12-15T22:16:37.978000+00:00
# 2  8e0659da8279539be416739ff8bf43a896b75cc4  2021-12-15T22:16:37.978000+00:00
# 3  01e6b76cfc0190483488a5e2b810015a62d142d4  2021-12-15T22:16:37.978000+00:00
# 4  8e7f79b211b5071c5c9faf34a25cc5e4d51b4bd7  2021-12-15T22:16:37.978000+00:00
#
#                                           discipline  \
# 0  Ensemble formations juridiques, économiques et...
# 1                                           Économie
# 2                                            Gestion
# 3                                            Gestion
# 4                             Lettres, langues, arts
#
#   salaire_brut_annuel_estime salaire_net_mensuel_regional_3eme_quartile  \
# 0                      27000                                       2240
# 1                         ns                                       2240
# 2                      27900                                       2240
# 3                      28200                                       2240
# 4                         ns                                       2240
#
#   salaire_net_mensuel_median_regional   cle_disc taux_de_reponse  \
# 0                                1860  disc01_18              78
# 1                                1860  disc03_18              81
# 2                                1860  disc04_18              75
# 3                                1860  disc04_30              75
# 4                                1860  disc06_18              63
#
#             etablissementactuel emplois_cadre_ou_professions_intermediaires  \
# 0  Université Côte d'Azur (UCA)                                          50
# 1  Université Côte d'Azur (UCA)                                          ns
# 2  Université Côte d'Azur (UCA)                                          56
# 3  Université Côte d'Azur (UCA)                                          54
# 4  Université Côte d'Azur (UCA)                                          ns
#
#   taux_dinsertion emplois_exterieurs_a_la_region_de_luniversite  \
# 0              96                                            34
# 1              90                                            ns
# 2             100                                            24
# 3              98                                            24
# 4              ns                                            ns
#
#   emplois_stables      diplome salaire_net_median_des_emplois_a_temps_plein  \
# 0              82  LICENCE PRO                                         1730
# 1              ns  LICENCE PRO                                           ns
# 2              90  LICENCE PRO                                         1790
# 3              94  LICENCE PRO                                         1810
# 4              ns  LICENCE PRO                                           ns
#
#   poids_de_la_discipline taux_de_chomage_regional code_du_domaine  \
# 0                     49                        9             DEG
# 1                     16                        9             DEG
# 2                     27                        9             DEG
# 3                     27                        9             DEG
# 4                      1                        9             LLA
#
#   emplois_a_temps_plein code_de_la_discipline de_diplomes_boursiers academie  \
# 0                    95                disc01                    14     Nice
# 1                    ns                disc03                    14     Nice
# 2                    92                disc04                    14     Nice
# 3                    96                disc04                    14     Nice
# 4                    ns                disc06                    14     Nice
#
#   numero_de_l_etablissement                     domaine nombre_de_reponses  \
# 0                  0060931E  Droit, économie et gestion                 91
# 1                  0060931E  Droit, économie et gestion                 29
# 2                  0060931E  Droit, économie et gestion                 49
# 3                  0060931E  Droit, économie et gestion                 49
# 4                  0060931E      Lettres, langues, arts                  3
#
#   femmes salaire_net_mensuel_regional_1er_quartile  \
# 0     60                                      1410
# 1     ns                                      1410
# 2     51                                      1410
# 3     51                                      1410
# 4     ns                                      1410
#
#                      cle_etab emplois_cadre                 situation annee  \
# 0  Nice - Sophia-Antipolis_18             7  18 mois après le diplôme  2018
# 1  Nice - Sophia-Antipolis_18            ns  18 mois après le diplôme  2018
# 2  Nice - Sophia-Antipolis_18             6  18 mois après le diplôme  2018
# 3  Nice - Sophia-Antipolis_30             6  30 mois après le diplôme  2018
# 4  Nice - Sophia-Antipolis_18            ns  18 mois après le diplôme  2018
#
#   id_paysage            etablissement code_de_l_academie remarque
# 0      7CYWd  Nice - Sophia-Antipolis                A23      NaN
# 1      7CYWd  Nice - Sophia-Antipolis                A23      NaN
# 2      7CYWd  Nice - Sophia-Antipolis                A23      NaN
# 3      7CYWd  Nice - Sophia-Antipolis                A23      NaN
# 4      7CYWd  Nice - Sophia-Antipolis                A23      NaN

# %% [markdown]
# ### Caractéristiques de etablissements

# %%
glob_data.head()
# Out:
#            datasetid                                  recordid  \
# 0  fr-esr-parcoursup  5ddd4059ccae7206ae2f39b37d08495258e52dff
# 1  fr-esr-parcoursup  a7f51872796481d96bbfcc6cfcc1fd13a8a291c3
# 2  fr-esr-parcoursup  94819eeabba33cc018ac8925f34d5b6fa795f0cd
# 3  fr-esr-parcoursup  119257913ef26bbfcdf0d2c46ab5ad87cc01a73e
# 4  fr-esr-parcoursup  74cdb514e03d75697a427dad4c50159336faf3b7
#
#                    record_timestamp  nb_voe_pp_at  nb_voe_pp_bp  nb_voe_pp_bg  \
# 0  2021-02-04T13:10:28.998000+00:00            21            19             4
# 1  2021-02-04T13:10:28.998000+00:00             9             8             3
# 2  2021-02-04T13:10:28.998000+00:00           158            26            28
# 3  2021-02-04T13:10:28.998000+00:00           113            38            61
# 4  2021-02-04T13:10:28.998000+00:00           256           114           134
#
#    pct_sansmention                                    fil_lib_voe_acc  \
# 0        30.769231                                   Métiers de l'eau
# 1         0.000000  Analyse, conduite et stratégie de l'entreprise...
# 2        50.000000                             Aménagements paysagers
# 3        62.500000                 Gestion et protection de la nature
# 4        66.666667                 Management Commercial Opérationnel
#
#    acc_brs  acc_bg       tri  acc_bg_mention session  form_lib_voe_acc  \
# 0        9       1  2_Lycées               0    2020  BTS - Production
# 1        0       0  2_Lycées               0    2020    BTS - Agricole
# 2        0       1  2_Lycées               0    2020    BTS - Agricole
# 3        1       3  2_Lycées               1    2020    BTS - Agricole
# 4        1       7  2_Lycées               2    2020    BTS - Services
#
#   cod_aff_form fili                                     lien_form_psup  \
# 0        23320  BTS  https://dossier.parcoursup.fr/Candidat/carte?A...
# 1        23461  BTS  https://dossier.parcoursup.fr/Candidat/carte?A...
# 2        23462  BTS  https://dossier.parcoursup.fr/Candidat/carte?A...
# 3        23464  BTS  https://dossier.parcoursup.fr/Candidat/carte?A...
# 4        24303  BTS  https://dossier.parcoursup.fr/Candidat/carte?A...
#
#    prop_tot_bp_brs         acad_mies  taux_adm_psup_gen        contrat_etab  \
# 0              3.0        La Réunion                6.0              Public
# 1              2.0  Clermont-Ferrand                0.0              Public
# 2              8.0  Clermont-Ferrand               25.0              Public
# 3              6.0  Clermont-Ferrand               50.0              Public
# 4             13.0          Grenoble               47.0  Privé hors contrat
#
#    pct_bp_mention ran_grp3  acc_finpp  acc_pc  nb_cla_pp_bg  acc_bt  \
# 0           15.38        4       13.0       1             3      10
# 1          100.00       10        1.0       0             3       0
# 2           50.00       23        3.0       1            22       0
# 3           12.50       29       18.0       1            42       3
# 4            8.33       93       14.0       0            93       3
#
#    nb_cla_pp_bt_brs  nb_voe_pp_bt  prop_tot_bg_brs  taux_adm_psup_pro  \
# 0                38            96              2.0               13.0
# 1                 2            11              0.0              100.0
# 2                13            53              4.0               25.0
# 3                 5            45              2.0               25.0
# 4                35           173             12.0               13.0
#
#    pct_aca_orig  prop_tot_bt  acc_pp  voe_tot  nb_voe_pp  \
# 0         92.31         37.0      15      145        140
# 1          0.00          9.0       1       46         31
# 2          0.00         40.0       3      455        265
# 3          0.00         15.0      18      271        257
# 4        100.00         84.0      15      729        677
#
#                                     lib_comp_voe_ins   cod_uai  \
# 0  Lycée de St Paul 4 - BTS - Production - Métier...  9741380G
# 1  AgroSup Dijon Direction Enseignement à Distanc...  0632001H
# 2  AgroSup Dijon Direction Enseignement à Distanc...  0632001H
# 3  AgroSup Dijon Direction Enseignement à Distanc...  0632001H
# 4  Ecole technique privée EPSECO - BTS - Services...  0261286G
#
#    pct_acc_debutpp  dep  prop_tot_bp  pct_tb  prop_tot_bt_brs pct_etab_orig  \
# 0            12.50  974          4.0     0.0             22.0          7.69
# 1           100.00   63          8.0   100.0              2.0             0
# 2            25.00   63         21.0     0.0             10.0             0
# 3            10.00   63         13.0     0.0              3.0             0
# 4             6.67   26         23.0     0.0             26.0             0
#
#    pct_mention_nonrenseignee  acc_ab  acc_aca_orig  \
# 0                        0.0       6            12
# 1                        0.0       0             0
# 2                        0.0       1             0
# 3                        0.0       2             0
# 4                        0.0       4            12
#
#                                          g_ea_lib_vx     pct_ab  nb_voe_pc_bp  \
# 0                                 Lycée de St Paul 4  46.153846             3
# 1  AgroSup Dijon Direction Enseignement à Distanc...   0.000000             2
# 2  AgroSup Dijon Direction Enseignement à Distanc...  50.000000            13
# 3  AgroSup Dijon Direction Enseignement à Distanc...  25.000000             2
# 4                      Ecole technique privée EPSECO  33.333333             0
#
#    pct_acc_finpp  nb_voe_pp_bg_brs  nb_cla_pp_bp  ran_grp1     pct_bg  \
# 0          81.25                 2            12      41.0   7.692308
# 1         100.00                 0             6       4.0   0.000000
# 2          75.00                 6            24      54.0  50.000000
# 3          90.00                 9            20      24.0  37.500000
# 4          93.33                23            90     117.0  58.333333
#
#    pct_bours  nb_voe_pc_at  acc_aca_orig_idf  pct_f  acc_bt_mention  \
# 0      69.23             1                12  12.50               7
# 1       0.00             9                 0   0.00               0
# 2       0.00           114                 0  50.00               0
# 3      12.50            10                 0  55.00               1
# 4       8.33            25                12  26.67               1
#
#    nb_cla_pp  acc_term  prop_tot  nb_voe_pc_bt  acc_datebac  acc_tot  \
# 0         90       1.0        47             1         12.0       16
# 1         20       0.0        25             3          1.0        1
# 2        126       0.0       117            36          3.0        4
# 3        148       0.0       107             0         15.0       20
# 4        317       0.0       192            16         10.0       15
#
#         region_etab_aff  nb_cla_pp_bg_brs     pct_bt  prop_tot_bg  \
# 0            La Réunion                 2  76.923077          3.0
# 1  Auvergne-Rhône-Alpes                 0   0.000000          3.0
# 2  Auvergne-Rhône-Alpes                 3   0.000000         25.0
# 3  Auvergne-Rhône-Alpes                 4  37.500000         26.0
# 4  Auvergne-Rhône-Alpes                15  25.000000         69.0
#
#    nb_voe_pp_bt_brs  acc_mention_nonrenseignee  nb_voe_pp_bp_brs  \
# 0                57                          0                13
# 1                 4                          0                 2
# 2                13                          0                10
# 3                13                          0                14
# 4                56                          0                55
#
#                                             lib_grp2  acc_bp_mention  \
# 0  Tous les candidats sauf les Bac technologiques...               2
# 1            Bacheliers professionnels toutes séries               1
# 2  Tous les candidats sauf les Bac technologiques...               1
# 3  Tous les candidats sauf les Bac technologiques...               1
# 4            Bacheliers professionnels toutes séries               1
#
#    acc_sansmention  acc_tb  prop_tot_at  capa_fin  acc_at  nb_cla_pp_at  \
# 0                4       0          3.0      15.0       3             8
# 1                0       1          5.0      20.0       0             3
# 2                1       0         31.0      20.0       2            35
# 3                5       0         53.0      30.0      12            64
# 4                8       0         16.0      40.0       3            24
#
#    acc_tot_f                                           lib_grp1  voe_tot_f  \
# 0          2            Bacheliers technologiques toutes séries         50
# 1          0  Tous les candidats sauf les Bac technologiques...         23
# 2          2            Bacheliers technologiques toutes séries        158
# 3         11            Bacheliers professionnels toutes séries        124
# 4          4            Bacheliers technologiques toutes séries        315
#
#    acc_neobac  nb_voe_pc  pct_bg_mention      pct_bp  acc_debutpp  acc_term_f  \
# 0          13          5            0.00   15.384615          2.0         0.0
# 1           1         15            0.00  100.000000          1.0         0.0
# 2           2        190            0.00   50.000000          1.0         0.0
# 3           8         14           12.50   25.000000          2.0         0.0
# 4          12         52           16.67   16.666667          1.0         0.0
#
#                                             lib_grp3  pct_neobac  \
# 0            Bacheliers professionnels toutes séries       81.25
# 1            Bacheliers technologiques toutes séries      100.00
# 2            Bacheliers professionnels toutes séries       50.00
# 3            Bacheliers technologiques toutes séries       40.00
# 4  Tous les candidats sauf les Bac technologiques...       80.00
#
#    pct_aca_orig_idf  nb_cla_pc  nb_cla_pp_bp_brs      pct_b  \
# 0             92.31          1                10  23.076923
# 1              0.00          5                 2   0.000000
# 2              0.00         21                 9   0.000000
# 3              0.00          4                 8  12.500000
# 4            100.00          8                45   0.000000
#
#   g_olocalisation_des_formations  taux_adm_psup  pct_bt_mention  nb_cla_pp_bt  \
# 0            [-20.9794, 55.3165]           34.0           53.85            67
# 1              [45.7749, 3.1766]           65.0            0.00             8
# 2              [45.7749, 3.1766]           46.0            0.00            45
# 3              [45.7749, 3.1766]           52.0           12.50            22
# 4             [44.9379, 4.89731]           34.0            8.33           110
#
#   ran_grp2  nb_voe_pc_bg      dep_lib  acc_bp          select_form  acc_b  \
# 0        3             0   La Réunion       2  formation selective      3
# 1        6             1  Puy-de-Dôme       1  formation selective      0
# 2       44            27  Puy-de-Dôme       1  formation selective      0
# 3       80             2  Puy-de-Dôme       2  formation selective      1
# 4       22            11        Drôme       2  formation selective      0
#
#    pct_acc_datebac  taux_adm_psup_techno geometry.type geometry.coordinates  \
# 0            75.00                  81.0         Point  [55.3165, -20.9794]
# 1           100.00                   0.0         Point    [3.1766, 45.7749]
# 2            75.00                  50.0         Point    [3.1766, 45.7749]
# 3            75.00                  25.0         Point    [3.1766, 45.7749]
# 4            66.67                  40.0         Point   [4.89731, 44.9379]
#
#   detail_forma  nb_cla_pp_internat  nb_voe_pp_internat  acc_internat  \
# 0          NaN                 NaN                 NaN           NaN
# 1          NaN                 NaN                 NaN           NaN
# 2          NaN                 NaN                 NaN           NaN
# 3          NaN                 NaN                 NaN           NaN
# 4          NaN                 NaN                 NaN           NaN
#
#    nb_cla_pp_pasinternat regr_forma lib_grp5 ran_grp4 ran_grp5 lib_grp4
# 0                    NaN        NaN      NaN      NaN      NaN      NaN
# 1                    NaN        NaN      NaN      NaN      NaN      NaN
# 2                    NaN        NaN      NaN      NaN      NaN      NaN
# 3                    NaN        NaN      NaN      NaN      NaN      NaN
# 4                    NaN        NaN      NaN      NaN      NaN      NaN

# %% [markdown]
# ## 1-  profils des étab(nb par sexe, etab d'origine, nouveau bacheliers)

# %%
import matplotlib.pyplot as plt

# %%
# types des étblissements
fig = plt.figure(figsize=(8,8))

tri = glob_data
tri['eff'] = 1
tri = tri.groupby('tri').sum()

plt.pie(x = tri['eff'],
        labels = list(tri.eff.index),
       autopct= lambda x : str(round(x,2))+"%",
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1a0d695f0a0>,
#   <matplotlib.patches.Wedge at 0x1a0d695f820>,
#   <matplotlib.patches.Wedge at 0x1a0d695ff40>],
#  [Text(0.5933372571127745, 0.9262563896254047, '1_universités'),
#   Text(-1.0360288169936123, -0.3696542849187825, '2_Lycées'),
#   Text(0.870099186606666, -0.6729988153529087, '3_Autres formations')],
#  [Text(0.3236385038796951, 0.5052307579774934, '31.87%'),
#   Text(-0.5651066274510612, -0.2016296099556995, '47.18%'),
#   Text(0.47459955633090867, -0.3670902629197684, '20.96%')])

# %%
# Statuts des étblissements
fig = plt.figure(figsize=(8,8))
contrat = glob_data
contrat['eff'] = 1
contrat = glob_data.groupby('contrat_etab').sum()
labels = list(contrat.eff.index)
plt.pie(x = contrat['eff'],
        labels=labels,
       autopct= lambda x : str(round(x,2))+"%",
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1a0d4d346d0>,
#   <matplotlib.patches.Wedge at 0x1a0d4d34e50>,
#   <matplotlib.patches.Wedge at 0x1a0d4d435b0>,
#   <matplotlib.patches.Wedge at 0x1a0d4d43cd0>],
#  [Text(1.0906128992016586, 0.14339980507292477, 'Privé enseignement supérieur'),
#   Text(1.0577024820101675, 0.302101737084598, 'Privé hors contrat'),
#   Text(0.7782003537354096, 0.7774343762955711, "Privé sous contrat d'association"),
#   Text(-0.8839918786390341, -0.6546436882001013, 'Public')],
#  [Text(0.5948797632009046, 0.0782180754943226, '4.16%'),
#   Text(0.5769286265510004, 0.16478276568250796, '0.53%'),
#   Text(0.4244729202193143, 0.4240551143430387, '15.6%'),
#   Text(-0.482177388348564, -0.3570783753818734, '79.71%')])

# %% [markdown]
# Les établissements demandés par les néo-bacheliers et étudiants en réorientation ou reprise sont pour la plupart publics. En effet, près de 80% de ses établissements ont le status public. Ils sont suivis par les établissements avec le status "Privé sous contrat d'association" (15,6%). Les autres établissements sont en faible proportion avec respectivement 4,16% et 0,53% pour les status "Privé enseignement supérieur" et "Privé hors contrat"

# %%
fig = plt.figure(figsize=(8,8))
selectivite = glob_data
selectivite['eff'] = 1
selectivite = selectivite.groupby('select_form').sum()

plt.pie(x = selectivite['eff'],
        labels = list(selectivite.eff.index),
       autopct= lambda x : str(round(x,2))+"%",
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1a0d34637c0>,
#   <matplotlib.patches.Wedge at 0x1a0d3463f40>],
#  [Text(0.8615803589508492, 0.683870810219391, 'formation non selec'),
#   Text(-0.8615804229794518, -0.6838707295524127, 'formation selective')],
#  [Text(0.46995292306409947, 0.3730204419378496, '21.36%'),
#   Text(-0.46995295798879183, -0.3730203979376796, '78.64%')])

# %% [markdown]
# sele

# %%
sele_tri = glob_data[['select_form','tri']].pivot_table(index='tri',
                                                  columns='select_form', 
                                                  aggfunc=len,margins=True,
                                                  margins_name="Total")
sele_tri.reset_index(inplace=True)

# %%
sele_tri
# Out:
# select_form                  tri  formation non selec  formation selective  \
# 0                  1_universités               2725.0               1341.0
# 1                       2_Lycées                  NaN               6020.0
# 2            3_Autres formations                  NaN               2674.0
# 3                          Total               2725.0              10035.0
#
# select_form  Total
# 0             4066
# 1             6020
# 2             2674
# 3            12760

# %%
sele_tri = pd.melt(sele_tri,id_vars="tri", value_vars=['formation non selec','formation selective'], var_name ='selectivite',value_name = "effectif")

# %%
sele_tri
# Out:
#                    tri          selectivite  effectif
# 0        1_universités  formation non selec    2725.0
# 1             2_Lycées  formation non selec       NaN
# 2  3_Autres formations  formation non selec       NaN
# 3                Total  formation non selec    2725.0
# 4        1_universités  formation selective    1341.0
# 5             2_Lycées  formation selective    6020.0
# 6  3_Autres formations  formation selective    2674.0
# 7                Total  formation selective   10035.0

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=sele_tri["tri"],y=sele_tri["effectif"],hue = sele_tri["selectivite"])
# Out:
# <AxesSubplot:xlabel='tri', ylabel='effectif'>

# %%
contr_tri = glob_data[['contrat_etab','tri']].pivot_table(index='tri',
                                                   columns='contrat_etab',
                                                   aggfunc=len,margins=True,
                                                   margins_name="Total")
contr_tri
# Out:
# contrat_etab         Privé enseignement supérieur  Privé hors contrat  \
# tri
# 1_universités                                 182                   1
# 2_Lycées                                       27                  30
# 3_Autres formations                           322                  37
# Total                                         531                  68
#
# contrat_etab         Privé sous contrat d'association  Public  Total
# tri
# 1_universités                                       2    3881   4066
# 2_Lycées                                         1396    4567   6020
# 3_Autres formations                               592    1723   2674
# Total                                            1990   10171  12760

# %% [markdown]
# ###### Filière de formation très agrégée

# %%
# Filière de formation très agrégée

fig = plt.figure(figsize=(12,6))
ax = fig.add_axes([0,0,1,1])
labels = list(fili.eff.index)
ax.barh(labels,fili["eff"]/glob_data.shape[0])
plt.xlabel("Proportion")
plt.ylabel("Filière de formation très agrégée")
plt.legend
plt.show()

# %% [markdown]
# ^pppp

# %% [markdown]
# # BROUILLON

# %%
columns_names = pd.json_normalize(req.json()['facet_groups'][:])

# %%
columns_names = list(ses_2020.columns)
columns_names1 = [c.replace('fields.', '') for c in columns_names ]

# %%
dic=dict()
for i in range(len(columns_names)) :
    dic[columns_names[i]] = columns_names1[i]
ses_2020.rename(dic)
# Out:
#               datasetid                                  recordid  \
# 0     fr-esr-parcoursup  5ddd4059ccae7206ae2f39b37d08495258e52dff
# 1     fr-esr-parcoursup  a7f51872796481d96bbfcc6cfcc1fd13a8a291c3
# 2     fr-esr-parcoursup  94819eeabba33cc018ac8925f34d5b6fa795f0cd
# 3     fr-esr-parcoursup  119257913ef26bbfcdf0d2c46ab5ad87cc01a73e
# 4     fr-esr-parcoursup  74cdb514e03d75697a427dad4c50159336faf3b7
# ...                 ...                                       ...
# 6015  fr-esr-parcoursup  99bbf6cc471058ca9dd3f557ed746a786d44df37
# 6016  fr-esr-parcoursup  4d792211dad63ba1226856b3d1117916857b79be
# 6017  fr-esr-parcoursup  9ab7d2fdd7be9f0f4a02cc0526d9eb74ce2d402c
# 6018  fr-esr-parcoursup  8f43abd8119a3a6adc722b0a95ab6518c1e004ed
# 6019  fr-esr-parcoursup  d360d13dfc0e523272f1d313927d59608b6844b4
#
#                       record_timestamp  fields.nb_voe_pp_at  \
# 0     2021-02-04T13:10:28.998000+00:00                   21
# 1     2021-02-04T13:10:28.998000+00:00                    9
# 2     2021-02-04T13:10:28.998000+00:00                  158
# 3     2021-02-04T13:10:28.998000+00:00                  113
# 4     2021-02-04T13:10:28.998000+00:00                  256
# ...                                ...                  ...
# 6015  2021-02-04T13:10:28.998000+00:00                   26
# 6016  2021-02-04T13:10:28.998000+00:00                    7
# 6017  2021-02-04T13:10:28.998000+00:00                    0
# 6018  2021-02-04T13:10:28.998000+00:00                    0
# 6019  2021-02-04T13:10:28.998000+00:00                    0
#
#       fields.nb_voe_pp_bp  fields.nb_voe_pp_bg  fields.pct_sansmention  \
# 0                      19                    4               30.769231
# 1                       8                    3                0.000000
# 2                      26                   28               50.000000
# 3                      38                   61               62.500000
# 4                     114                  134               66.666667
# ...                   ...                  ...                     ...
# 6015                   42                    7               41.666667
# 6016                    6                    5               83.333333
# 6017                    0                    0               59.090909
# 6018                    0                    0               58.823529
# 6019                    0                    0               90.625000
#
#                                  fields.fil_lib_voe_acc  fields.acc_brs  \
# 0                                      Métiers de l'eau               9
# 1     Analyse, conduite et stratégie de l'entreprise...               0
# 2                                Aménagements paysagers               0
# 3                    Gestion et protection de la nature               1
# 4                    Management Commercial Opérationnel               1
# ...                                                 ...             ...
# 6015      Gestion des transports et logistique associée               3
# 6016                                  Gestion de la PME               0
# 6017                 Management Commercial Opérationnel               8
# 6018                 Management Commercial Opérationnel               8
# 6019                                  Gestion de la PME              10
#
#       fields.acc_bg fields.tri  fields.acc_bg_mention fields.session  \
# 0                 1   2_Lycées                      0           2020
# 1                 0   2_Lycées                      0           2020
# 2                 1   2_Lycées                      0           2020
# 3                 3   2_Lycées                      1           2020
# 4                 7   2_Lycées                      2           2020
# ...             ...        ...                    ...            ...
# 6015              1   2_Lycées                      0           2020
# 6016              3   2_Lycées                      0           2020
# 6017              3   2_Lycées                      0           2020
# 6018              1   2_Lycées                      0           2020
# 6019              0   2_Lycées                      0           2020
#
#      fields.form_lib_voe_acc fields.cod_aff_form fields.fili  \
# 0           BTS - Production               23320         BTS
# 1             BTS - Agricole               23461         BTS
# 2             BTS - Agricole               23462         BTS
# 3             BTS - Agricole               23464         BTS
# 4             BTS - Services               24303         BTS
# ...                      ...                 ...         ...
# 6015          BTS - Services               30070         BTS
# 6016          BTS - Services               30183         BTS
# 6017          BTS - Services               30554         BTS
# 6018          BTS - Services               30562         BTS
# 6019          BTS - Services               30575         BTS
#
#                                   fields.lien_form_psup  \
# 0     https://dossier.parcoursup.fr/Candidat/carte?A...
# 1     https://dossier.parcoursup.fr/Candidat/carte?A...
# 2     https://dossier.parcoursup.fr/Candidat/carte?A...
# 3     https://dossier.parcoursup.fr/Candidat/carte?A...
# 4     https://dossier.parcoursup.fr/Candidat/carte?A...
# ...                                                 ...
# 6015  https://dossier.parcoursup.fr/Candidat/carte?A...
# 6016  https://dossier.parcoursup.fr/Candidat/carte?A...
# 6017  https://dossier.parcoursup.fr/Candidat/carte?A...
# 6018  https://dossier.parcoursup.fr/Candidat/carte?A...
# 6019  https://dossier.parcoursup.fr/Candidat/carte?A...
#
#       fields.prop_tot_bp_brs  fields.acad_mies  fields.taux_adm_psup_gen  \
# 0                        3.0        La Réunion                       6.0
# 1                        2.0  Clermont-Ferrand                       0.0
# 2                        8.0  Clermont-Ferrand                      25.0
# 3                        6.0  Clermont-Ferrand                      50.0
# 4                       13.0          Grenoble                      47.0
# ...                      ...               ...                       ...
# 6015                     7.0          Toulouse                       7.0
# 6016                     2.0       Montpellier                      57.0
# 6017                     6.0          Grenoble                      12.0
# 6018                     7.0            Rennes                       NaN
# 6019                     3.0        Versailles                       0.0
#
#                    fields.contrat_etab  fields.pct_bp_mention fields.ran_grp3  \
# 0                               Public                  15.38               4
# 1                               Public                 100.00              10
# 2                               Public                  50.00              23
# 3                               Public                  12.50              29
# 4                   Privé hors contrat                   8.33              93
# ...                                ...                    ...             ...
# 6015  Privé sous contrat d'association                  50.00              21
# 6016      Privé enseignement supérieur                   0.00               8
# 6017                            Public                  18.18             NaN
# 6018                            Public                  35.29             NaN
# 6019                            Public                   6.25             NaN
#
#       fields.acc_finpp  fields.acc_pc  fields.nb_cla_pp_bg  fields.acc_bt  \
# 0                 13.0              1                    3             10
# 1                  1.0              0                    3              0
# 2                  3.0              1                   22              0
# 3                 18.0              1                   42              3
# 4                 14.0              0                   93              3
# ...                ...            ...                  ...            ...
# 6015              15.0              1                    5              2
# 6016               5.0              4                    5              3
# 6017               3.0             25                    0             12
# 6018              11.0             16                    0              5
# 6019               0.0              0                    0             26
#
#       fields.nb_cla_pp_bt_brs  fields.nb_voe_pp_bt  fields.prop_tot_bg_brs  \
# 0                          38                   96                     2.0
# 1                           2                   11                     0.0
# 2                          13                   53                     4.0
# 3                           5                   45                     2.0
# 4                          35                  173                    12.0
# ...                       ...                  ...                     ...
# 6015                        6                   19                     1.0
# 6016                        2                    7                     2.0
# 6017                        0                    0                     1.0
# 6018                        0                    0                     0.0
# 6019                        0                    0                     0.0
#
#       fields.taux_adm_psup_pro  fields.pct_aca_orig  fields.prop_tot_bt  \
# 0                         13.0                92.31                37.0
# 1                        100.0                 0.00                 9.0
# 2                         25.0                 0.00                40.0
# 3                         25.0                 0.00                15.0
# 4                         13.0               100.00                84.0
# ...                        ...                  ...                 ...
# 6015                      67.0                91.67                18.0
# 6016                       0.0                66.67                10.0
# 6017                      27.0                90.91                31.0
# 6018                       NaN               100.00                10.0
# 6019                      24.0                96.88                53.0
#
#       fields.acc_pp  fields.voe_tot  fields.nb_voe_pp  \
# 0                15             145               140
# 1                 1              46                31
# 2                 3             455               265
# 3                18             271               257
# 4                15             729               677
# ...             ...             ...               ...
# 6015             14             107                94
# 6016              3              62                25
# 6017              0             258                 0
# 6018              0              90                 0
# 6019              0               0                 0
#
#                                 fields.lib_comp_voe_ins fields.cod_uai  \
# 0     Lycée de St Paul 4 - BTS - Production - Métier...       9741380G
# 1     AgroSup Dijon Direction Enseignement à Distanc...       0632001H
# 2     AgroSup Dijon Direction Enseignement à Distanc...       0632001H
# 3     AgroSup Dijon Direction Enseignement à Distanc...       0632001H
# 4     Ecole technique privée EPSECO - BTS - Services...       0261286G
# ...                                                 ...            ...
# 6015  Lycée professionnel Saint-Dominique - BTS - Se...       0810100U
# 6016  IDELCA Business School - BTS - Services - Gest...       0340994W
# 6017  Lycée Emmanuel Mounier - BTS - Services - Mana...       0380032D
# 6018  Lycée professionnel Jean Moulin - BTS - Servic...       0220059V
# 6019  Lycée professionnel Turgot - BTS - Services - ...       0951281B
#
#       fields.pct_acc_debutpp fields.dep  fields.prop_tot_bp  fields.pct_tb  \
# 0                      12.50        974                 4.0       0.000000
# 1                     100.00         63                 8.0     100.000000
# 2                      25.00         63                21.0       0.000000
# 3                      10.00         63                13.0       0.000000
# 4                       6.67         26                23.0       0.000000
# ...                      ...        ...                 ...            ...
# 6015                   53.33         81                19.0       8.333333
# 6016                   28.57         34                 9.0       0.000000
# 6017                    0.00         38                18.0       0.000000
# 6018                    0.00         22                14.0       0.000000
# 6019                    0.00         95                 9.0       0.000000
#
#       fields.prop_tot_bt_brs fields.pct_etab_orig  \
# 0                       22.0                 7.69
# 1                        2.0                    0
# 2                       10.0                    0
# 3                        3.0                    0
# 4                       26.0                    0
# ...                      ...                  ...
# 6015                     6.0                   50
# 6016                     2.0                    0
# 6017                     8.0                13.64
# 6018                     2.0                35.29
# 6019                    17.0                 9.38
#
#       fields.pct_mention_nonrenseignee  fields.acc_ab  fields.acc_aca_orig  \
# 0                                  0.0              6                   12
# 1                                  0.0              0                    0
# 2                                  0.0              1                    0
# 3                                  0.0              2                    0
# 4                                  0.0              4                   12
# ...                                ...            ...                  ...
# 6015                               0.0              3                   11
# 6016                               0.0              0                    4
# 6017                               0.0              8                   20
# 6018                               0.0              6                   17
# 6019                               0.0              3                   31
#
#                                      fields.g_ea_lib_vx  fields.pct_ab  \
# 0                                    Lycée de St Paul 4      46.153846
# 1     AgroSup Dijon Direction Enseignement à Distanc...       0.000000
# 2     AgroSup Dijon Direction Enseignement à Distanc...      50.000000
# 3     AgroSup Dijon Direction Enseignement à Distanc...      25.000000
# 4                         Ecole technique privée EPSECO      33.333333
# ...                                                 ...            ...
# 6015                Lycée professionnel Saint-Dominique      25.000000
# 6016                             IDELCA Business School       0.000000
# 6017                             Lycée Emmanuel Mounier      36.363636
# 6018                    Lycée professionnel Jean Moulin      35.294118
# 6019                         Lycée professionnel Turgot       9.375000
#
#       fields.nb_voe_pc_bp  fields.pct_acc_finpp  fields.nb_voe_pp_bg_brs  \
# 0                       3                 81.25                        2
# 1                       2                100.00                        0
# 2                      13                 75.00                        6
# 3                       2                 90.00                        9
# 4                       0                 93.33                       23
# ...                   ...                   ...                      ...
# 6015                    0                100.00                        1
# 6016                   11                 71.43                        2
# 6017                   55                  9.09                        0
# 6018                   23                 64.71                        0
# 6019                    0                  0.00                        0
#
#       fields.nb_cla_pp_bp  fields.ran_grp1  fields.pct_bg  fields.pct_bours  \
# 0                      12             41.0       7.692308             69.23
# 1                       6              4.0       0.000000              0.00
# 2                      24             54.0      50.000000              0.00
# 3                      20             24.0      37.500000             12.50
# 4                      90            117.0      58.333333              8.33
# ...                   ...              ...            ...               ...
# 6015                   39             24.0       8.333333             25.00
# 6016                    6              7.0      50.000000              0.00
# 6017                    0              NaN      13.636364             36.36
# 6018                    0              NaN       5.882353             47.06
# 6019                    0              NaN       0.000000             31.25
#
#       fields.nb_voe_pc_at  fields.acc_aca_orig_idf  fields.pct_f  \
# 0                       1                       12         12.50
# 1                       9                        0          0.00
# 2                     114                        0         50.00
# 3                      10                        0         55.00
# 4                      25                       12         26.67
# ...                   ...                      ...           ...
# 6015                    6                       11          6.67
# 6016                   14                        4         28.57
# 6017                   90                       20         57.58
# 6018                   36                       17         41.18
# 6019                    0                       31         38.24
#
#       fields.acc_bt_mention  fields.nb_cla_pp  fields.acc_term  \
# 0                         7                90                1
# 1                         0                20                0
# 2                         0               126                0
# 3                         1               148                0
# 4                         1               317                0
# ...                     ...               ...              ...
# 6015                      1                78                6
# 6016                      1                24                0
# 6017                      5                 0                3
# 6018                      1                 0                6
# 6019                      1                 0                3
#
#       fields.prop_tot  fields.nb_voe_pc_bt  fields.acc_datebac  \
# 0                  47                    1                12.0
# 1                  25                    3                 1.0
# 2                 117                   36                 3.0
# 3                 107                    0                15.0
# 4                 192                   16                10.0
# ...               ...                  ...                 ...
# 6015               55                    6                12.0
# 6016               39                    7                 3.0
# 6017               71                  105                 0.0
# 6018               25                   26                 0.0
# 6019               65                    0                 0.0
#
#       fields.acc_tot fields.region_etab_aff  fields.nb_cla_pp_bg_brs  \
# 0                 16             La Réunion                        2
# 1                  1   Auvergne-Rhône-Alpes                        0
# 2                  4   Auvergne-Rhône-Alpes                        3
# 3                 20   Auvergne-Rhône-Alpes                        4
# 4                 15   Auvergne-Rhône-Alpes                       15
# ...              ...                    ...                      ...
# 6015              15              Occitanie                        1
# 6016               7              Occitanie                        2
# 6017              33   Auvergne-Rhône-Alpes                        0
# 6018              17               Bretagne                        0
# 6019              34          Ile-de-France                        0
#
#       fields.pct_bt  fields.prop_tot_bg  fields.nb_voe_pp_bt_brs  \
# 0         76.923077                 3.0                       57
# 1          0.000000                 3.0                        4
# 2          0.000000                25.0                       13
# 3         37.500000                26.0                       13
# 4         25.000000                69.0                       56
# ...             ...                 ...                      ...
# 6015      16.666667                 5.0                        6
# 6016      50.000000                 8.0                        2
# 6017      54.545455                 6.0                        0
# 6018      29.411765                 1.0                        0
# 6019      81.250000                 1.0                        0
#
#       fields.acc_mention_nonrenseignee  fields.nb_voe_pp_bp_brs  \
# 0                                    0                       13
# 1                                    0                        2
# 2                                    0                       10
# 3                                    0                       14
# 4                                    0                       55
# ...                                ...                      ...
# 6015                                 0                       18
# 6016                                 0                        1
# 6017                                 0                        0
# 6018                                 0                        0
# 6019                                 0                        0
#
#                                         fields.lib_grp2  \
# 0     Tous les candidats sauf les Bac technologiques...
# 1               Bacheliers professionnels toutes séries
# 2     Tous les candidats sauf les Bac technologiques...
# 3     Tous les candidats sauf les Bac technologiques...
# 4               Bacheliers professionnels toutes séries
# ...                                                 ...
# 6015  Tous les candidats sauf les Bac technologiques...
# 6016            Bacheliers professionnels toutes séries
# 6017                                                NaN
# 6018                                                NaN
# 6019                                                NaN
#
#       fields.acc_bp_mention  fields.acc_sansmention  fields.acc_tb  \
# 0                         2                       4              0
# 1                         1                       0              1
# 2                         1                       1              0
# 3                         1                       5              0
# 4                         1                       8              0
# ...                     ...                     ...            ...
# 6015                      6                       5              1
# 6016                      0                       5              0
# 6017                      4                      13              0
# 6018                      6                      10              0
# 6019                      2                      29              0
#
#       fields.prop_tot_at  fields.capa_fin  fields.acc_at  fields.nb_cla_pp_at  \
# 0                    3.0               15              3                    8
# 1                    5.0               20              0                    3
# 2                   31.0               20              2                   35
# 3                   53.0               30             12                   64
# 4                   16.0               40              3                   24
# ...                  ...              ...            ...                  ...
# 6015                13.0               18              3                   16
# 6016                12.0               12              1                    7
# 6017                16.0               34             11                    0
# 6018                 0.0               18              0                    0
# 6019                 2.0               35              2                    0
#
#       fields.acc_tot_f                                    fields.lib_grp1  \
# 0                    2            Bacheliers technologiques toutes séries
# 1                    0  Tous les candidats sauf les Bac technologiques...
# 2                    2            Bacheliers technologiques toutes séries
# 3                   11            Bacheliers professionnels toutes séries
# 4                    4            Bacheliers technologiques toutes séries
# ...                ...                                                ...
# 6015                 1            Bacheliers technologiques toutes séries
# 6016                 2            Bacheliers technologiques toutes séries
# 6017                19                                                NaN
# 6018                 7                                                NaN
# 6019                13                                                NaN
#
#       fields.voe_tot_f  fields.acc_neobac  fields.nb_voe_pc  \
# 0                   50                 13                 5
# 1                   23                  1                15
# 2                  158                  2               190
# 3                  124                  8                14
# 4                  315                 12                52
# ...                ...                ...               ...
# 6015                27                 12                13
# 6016                28                  6                37
# 6017               122                 22               258
# 6018                36                 17                90
# 6019                 0                 32                 0
#
#       fields.pct_bg_mention  fields.pct_bp  fields.acc_debutpp  \
# 0                      0.00      15.384615                 2.0
# 1                      0.00     100.000000                 1.0
# 2                      0.00      50.000000                 1.0
# 3                     12.50      25.000000                 2.0
# 4                     16.67      16.666667                 1.0
# ...                     ...            ...                 ...
# 6015                   0.00      75.000000                 8.0
# 6016                   0.00       0.000000                 2.0
# 6017                   0.00      31.818182                 0.0
# 6018                   0.00      64.705882                 0.0
# 6019                   0.00      18.750000                 0.0
#
#       fields.acc_term_f                                    fields.lib_grp3  \
# 0                     0            Bacheliers professionnels toutes séries
# 1                     0            Bacheliers technologiques toutes séries
# 2                     0            Bacheliers professionnels toutes séries
# 3                     0            Bacheliers technologiques toutes séries
# 4                     0  Tous les candidats sauf les Bac technologiques...
# ...                 ...                                                ...
# 6015                  0            Bacheliers professionnels toutes séries
# 6016                  0  Tous les candidats sauf les Bac technologiques...
# 6017                  3                                                NaN
# 6018                  3                                                NaN
# 6019                  0                                                NaN
#
#       fields.pct_neobac  fields.pct_aca_orig_idf  fields.nb_cla_pc  \
# 0                 81.25                    92.31                 1
# 1                100.00                     0.00                 5
# 2                 50.00                     0.00                21
# 3                 40.00                     0.00                 4
# 4                 80.00                   100.00                 8
# ...                 ...                      ...               ...
# 6015              80.00                    91.67                 5
# 6016              85.71                    66.67                15
# 6017              66.67                    90.91                42
# 6018             100.00                   100.00                19
# 6019              94.12                    96.88                 0
#
#       fields.nb_cla_pp_bp_brs  fields.pct_b  \
# 0                          10     23.076923
# 1                           2      0.000000
# 2                           9      0.000000
# 3                           8     12.500000
# 4                          45      0.000000
# ...                       ...           ...
# 6015                       16     25.000000
# 6016                        1     16.666667
# 6017                        0      4.545455
# 6018                        0      5.882353
# 6019                        0      0.000000
#
#      fields.g_olocalisation_des_formations  fields.taux_adm_psup  \
# 0                      [-20.9794, 55.3165]                  34.0
# 1                        [45.7749, 3.1766]                  65.0
# 2                        [45.7749, 3.1766]                  46.0
# 3                        [45.7749, 3.1766]                  52.0
# 4                       [44.9379, 4.89731]                  34.0
# ...                                    ...                   ...
# 6015                     [43.9298, 2.1477]                  59.0
# 6016                    [43.6567, 3.91005]                  96.0
# 6017                   [45.17942, 5.73096]                   NaN
# 6018                    [48.5238, -2.7884]                   NaN
# 6019                    [48.9852, 2.32117]                   NaN
#
#       fields.pct_bt_mention  fields.nb_cla_pp_bt fields.ran_grp2  \
# 0                     53.85                   67               3
# 1                      0.00                    8               6
# 2                      0.00                   45              44
# 3                     12.50                   22              80
# 4                      8.33                  110              22
# ...                     ...                  ...             ...
# 6015                   8.33                   18              10
# 6016                  16.67                    6               9
# 6017                  22.73                    0             NaN
# 6018                   5.88                    0             NaN
# 6019                   3.13                    0             NaN
#
#       fields.nb_voe_pc_bg fields.dep_lib  fields.acc_bp   fields.select_form  \
# 0                       0     La Réunion              2  formation selective
# 1                       1    Puy-de-Dôme              1  formation selective
# 2                      27    Puy-de-Dôme              1  formation selective
# 3                       2    Puy-de-Dôme              2  formation selective
# 4                      11          Drôme              2  formation selective
# ...                   ...            ...            ...                  ...
# 6015                    1           Tarn              9  formation selective
# 6016                    5        Hérault              0  formation selective
# 6017                    8          Isère              7  formation selective
# 6018                    5  Côtes-d'armor             11  formation selective
# 6019                    0     Val-d'oise              6  formation selective
#
#       fields.acc_b  fields.pct_acc_datebac  fields.taux_adm_psup_techno  \
# 0                3                   75.00                         81.0
# 1                0                  100.00                          0.0
# 2                0                   75.00                         50.0
# 3                1                   75.00                         25.0
# 4                0                   66.67                         40.0
# ...            ...                     ...                          ...
# 6015             3                   80.00                         27.0
# 6016             1                   42.86                         43.0
# 6017             1                    0.00                         61.0
# 6018             1                    0.00                          NaN
# 6019             0                    0.00                         76.0
#
#      geometry.type geometry.coordinates fields.detail_forma  \
# 0            Point  [55.3165, -20.9794]                 NaN
# 1            Point    [3.1766, 45.7749]                 NaN
# 2            Point    [3.1766, 45.7749]                 NaN
# 3            Point    [3.1766, 45.7749]                 NaN
# 4            Point   [4.89731, 44.9379]                 NaN
# ...            ...                  ...                 ...
# 6015         Point    [2.1477, 43.9298]                 NaN
# 6016         Point   [3.91005, 43.6567]                 NaN
# 6017         Point  [5.73096, 45.17942]                 NaN
# 6018         Point   [-2.7884, 48.5238]                 NaN
# 6019         Point   [2.32117, 48.9852]                 NaN
#
#       fields.nb_cla_pp_internat  fields.nb_voe_pp_internat  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 6015                        NaN                        NaN
# 6016                        NaN                        NaN
# 6017                        NaN                        NaN
# 6018                        NaN                        NaN
# 6019                        NaN                        NaN
#
#       fields.acc_internat  fields.nb_cla_pp_pasinternat
# 0                     NaN                           NaN
# 1                     NaN                           NaN
# 2                     NaN                           NaN
# 3                     NaN                           NaN
# 4                     NaN                           NaN
# ...                   ...                           ...
# 6015                  NaN                           NaN
# 6016                  NaN                           NaN
# 6017                  NaN                           NaN
# 6018                  NaN                           NaN
# 6019                  NaN                           NaN
#
# [6020 rows x 115 columns]
